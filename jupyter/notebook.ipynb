# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../filtered_data/acidentes_filtrado_full.csv', sep=';')
df.head()
# Out:
#   data_inversa     dia_semana   horario   br     km       municipio  \
# 0   2019-01-02   quarta-feira  13:40:00  316    4,8        TERESINA
# 1   2019-01-03   quinta-feira  09:00:00  343      4        TERESINA
# 2   2019-01-03   quinta-feira  07:30:00  407    600           ACAUA
# 3   2019-01-05         sábado  06:20:00  316  317,2           PICOS
# 4   2019-01-07  segunda-feira  05:05:00  316  172,1  ELESBAO VELOSO
#
#                        causa_acidente              tipo_acidente  \
# 0         Defeito Mecânico no Veículo                   Incêndio
# 1  Não guardar distância de segurança           Colisão traseira
# 2         Falta de Atenção à Condução  Saída de leito carroçável
# 3  Não guardar distância de segurança           Colisão traseira
# 4         Falta de Atenção à Condução  Saída de leito carroçável
#
#   classificacao_acidente condicao_metereologica  ilesos  feridos_leves  \
# 0            Sem Vítimas                    Sol       1              0
# 1    Com Vítimas Feridas              Céu Claro       1              0
# 2    Com Vítimas Feridas              Céu Claro       0              1
# 3    Com Vítimas Feridas                    Sol       1              0
# 4     Com Vítimas Fatais                Nublado       0              0
#
#    feridos_graves  mortos   ano      mes
# 0               0       0  2019  janeiro
# 1               0       0  2019  janeiro
# 2               0       0  2019  janeiro
# 3               0       0  2019  janeiro
# 4               0       1  2019  janeiro

# %%
morte_ano = df.filter(items=['ano', 'mortos']).groupby('ano').sum().reset_index()

plt.bar(morte_ano['ano'], morte_ano['mortos'])
plt.title('Distribuição de mortes por ano')
plt.xlabel('ano')
plt.ylabel('mortos')
plt.show()

# %%
morte_mes = df.filter(items=['mes', 'mortos']).groupby('mes').sum().sort_values(by='mortos').reset_index()

fig, ax = plt.subplots()
ax.pie(morte_mes['mortos'], labels=morte_mes['mes'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x79c7f88b55b0>,
#   <matplotlib.patches.Wedge at 0x79c7f88b45f0>,
#   <matplotlib.patches.Wedge at 0x79c7f88b71a0>,
#   <matplotlib.patches.Wedge at 0x79c7f88b6e70>,
#   <matplotlib.patches.Wedge at 0x79c804d3f8c0>,
#   <matplotlib.patches.Wedge at 0x79c804d3eae0>,
#   <matplotlib.patches.Wedge at 0x79c804d3fe30>,
#   <matplotlib.patches.Wedge at 0x79c804d3ddc0>,
#   <matplotlib.patches.Wedge at 0x79c804d3ebd0>,
#   <matplotlib.patches.Wedge at 0x79c7f88b1ca0>,
#   <matplotlib.patches.Wedge at 0x79c7f88b2780>,
#   <matplotlib.patches.Wedge at 0x79c7f8faab70>],
#  [Text(1.0823866741295693, 0.19605888826250503, 'maio'),
#   Text(0.9272294864420061, 0.5918154099653825, 'abril'),
#   Text(0.605886554292544, 0.9180966633898133, 'fevereiro'),
#   Text(0.14635017721823987, 1.0902209068020068, 'março'),
#   Text(-0.3779733150235788, 1.0330228328212725, 'novembro'),
#   Text(-0.8182074720525376, 0.7352118964471372, 'setembro'),
#   Text(-1.072287311255055, 0.24535672422292581, 'outubro'),
#   Text(-1.0453816689275517, -0.34231150472960564, 'agosto'),
#   Text(-0.6937721537698025, -0.8536276698031817, 'junho'),
#   Text(-0.0921566341866896, -1.0961328180359262, 'julho'),
#   Text(0.5668617858775837, -0.9426917394947706, 'janeiro'),
#   Text(1.0315744603388683, -0.3819085398057668, 'dezembro')],
#  [Text(0.5903927313434014, 0.10694121177954818, '5.7%'),
#   Text(0.5057615380592759, 0.3228084054356632, '6.7%'),
#   Text(0.33048357506866033, 0.5007799982126254, '6.7%'),
#   Text(0.07982736939176718, 0.5946659491647309, '7.6%'),
#   Text(-0.20616726274013386, 0.563466999720694, '7.8%'),
#   Text(-0.44629498475592955, 0.40102467078934756, '7.8%'),
#   Text(-0.5848839879573027, 0.13383094048523225, '8.4%'),
#   Text(-0.5702081830513918, -0.1867153662161485, '8.9%'),
#   Text(-0.3784211747835286, -0.46561509261991724, '9.3%'),
#   Text(-0.050267255010921594, -0.597890628019596, '9.7%'),
#   Text(0.3091973377514093, -0.5141954942698749, '10.2%'),
#   Text(0.5626769783666553, -0.20831374898496366, '11.3%')])
